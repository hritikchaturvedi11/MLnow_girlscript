# %% [markdown]
# <a href="https://colab.research.google.com/github/hritikchaturvedi11/MLnow_girlscript/blob/main/EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.activity.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fexperimentsandconfigs%20https%3a%2f%2fwww.googleapis.com%2fauth%2fphotos.native&response_type=code
#
# Enter your authorization code:
# 4/1AY0e-g4Bbk7UfPAea1sXgSQeXexKwar6EtGTE3oiErF-cagGn-RIYuHuEd4
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/Machine Learning google colab/EDA/student'
# Out:
# /content/drive/MyDrive/Machine Learning google colab/EDA/student

# %%
ls
# Out:
# student-mat.csv     student-merge.R  student.txt
# student-mat.gsheet  student-por.csv

# %% [markdown]
# Importing the nessesary libraries

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
from tensorflow import keras

# %% [markdown]
# Importing the data

# %%
mathData = pd.read_csv('student-mat.csv',sep=';');

# %%
mathData.head(10)
# Out:
#   school sex  age address famsize Pstatus  ...  Walc  health absences  G1  G2  G3
# 0     GP   F   18       U     GT3       A  ...     1       3        6   5   6   6
# 1     GP   F   17       U     GT3       T  ...     1       3        4   5   5   6
# 2     GP   F   15       U     LE3       T  ...     3       3       10   7   8  10
# 3     GP   F   15       U     GT3       T  ...     1       5        2  15  14  15
# 4     GP   F   16       U     GT3       T  ...     2       5        4   6  10  10
# 5     GP   M   16       U     LE3       T  ...     2       5       10  15  15  15
# 6     GP   M   16       U     LE3       T  ...     1       3        0  12  12  11
# 7     GP   F   17       U     GT3       A  ...     1       1        6   6   5   6
# 8     GP   M   15       U     LE3       A  ...     1       1        0  16  18  19
# 9     GP   M   15       U     GT3       T  ...     1       5        0  14  15  15
#
# [10 rows x 33 columns]

# %%
print(f'school: {mathData.school.unique()}')
print(f'sex: {mathData.sex.unique()}')
print(f'address: {mathData.address.unique()}')
print(f'Mjob: {mathData.Mjob.unique()}')
print(f'Fjob: {mathData.Fjob.unique()}')
print(f'higher: {mathData.higher.unique()}')
# Out:
# school: ['GP' 'MS']
# sex: ['F' 'M']
# address: ['U' 'R']
# Mjob: ['at_home' 'health' 'other' 'services' 'teacher']
# Fjob: ['teacher' 'other' 'services' 'health' 'at_home']
# higher: ['yes' 'no']

# %%
#convert the categories into numbers 

#binary valued 

mathData['school'] = mathData['school'].apply({'GP':1, 'MS':0}.get)
mathData['sex'] = mathData['sex'].apply({'F':1, 'M':0}.get)
mathData['address'] = mathData['address'].apply({'U':1, 'R':0}.get)
mathData['higher'] = mathData['higher'].apply({'yes':1, 'no':0}.get)


#multi-valued
mathData['Mjob'] = mathData['Mjob'].apply({'at_home':1, 'health':2, 'other':3, 'services':4, 'teacher':5}.get)
mathData['Fjob'] = mathData['Fjob'].apply({'at_home':1, 'health':2, 'other':3, 'services':4, 'teacher':5}.get)

mathData.head(20)
# Out:
#     school  sex  address  Mjob  Fjob  ...  freetime  absences  G1  G2  G3
# 0        1    1        1     1     5  ...         3         6   5   6   6
# 1        1    1        1     1     3  ...         3         4   5   5   6
# 2        1    1        1     1     3  ...         3        10   7   8  10
# 3        1    1        1     2     4  ...         2         2  15  14  15
# 4        1    1        1     3     3  ...         3         4   6  10  10
# 5        1    0        1     4     3  ...         4        10  15  15  15
# 6        1    0        1     3     3  ...         4         0  12  12  11
# 7        1    1        1     3     5  ...         1         6   6   5   6
# 8        1    0        1     4     3  ...         2         0  16  18  19
# 9        1    0        1     3     3  ...         5         0  14  15  15
# 10       1    1        1     5     2  ...         3         0  10   8   9
# 11       1    1        1     4     3  ...         2         4  10  12  12
# 12       1    0        1     2     4  ...         3         2  14  14  14
# 13       1    0        1     5     3  ...         4         2  10  10  11
# 14       1    0        1     3     3  ...         5         0  14  16  16
# 15       1    1        1     2     3  ...         4         4  14  14  14
# 16       1    1        1     4     4  ...         2         6  13  14  14
# 17       1    1        1     3     3  ...         3         4   8  10  10
# 18       1    0        1     4     4  ...         5        16   6   5   5
# 19       1    0        1     2     3  ...         1         4   8  10  10
#
# [20 rows x 12 columns]

# %%
#selecting columns
mathData=mathData[['school','sex','address','Mjob','Fjob','higher','studytime','freetime','absences','G1','G2','G3']]

# %%
mathData.head(3)
# Out:
#    school  sex  address  Mjob  Fjob  ...  freetime  absences  G1  G2  G3
# 0       1    1        1     1     5  ...         3         6   5   6   6
# 1       1    1        1     1     3  ...         3         4   5   5   6
# 2       1    1        1     1     3  ...         3        10   7   8  10
#
# [3 rows x 12 columns]

# %%
mathData.to_csv('cleanMathData.csv') # export MathData as CleanMathData to a csv

# %%
ls
# Out:
# cleanMathData.csv  student-mat.gsheet  student-por.csv
# student-mat.csv    student-merge.R     student.txt

# %%
import seaborn as sns
sns.palplot(sns.color_palette('PuOr')) # Purple to orange colors
pal= sns.color_palette('PuOr',6) # Print 6 colors shades from purple to orange
pal.as_hex()  # set hex codes values for colors

import matplotlib.pyplot as plt
plt.style.use(['seaborn'])
sns_colors = ['#c6690c','#664697'] # orange color hex codes
sns.set_palette(sns_colors)  # set the pallete for sns colors
sns.palplot(sns.color_palette(sns_colors))  # plot the color codes

# %%
mathData.columns
# Out:
# Index(['school', 'sex', 'address', 'Mjob', 'Fjob', 'higher', 'studytime',
#        'freetime', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
# Pairplot for all the data

sns.pairplot(mathData,
    x_vars=['school', 'sex', 'address', 'Mjob', 'Fjob', 'higher', 'studytime',
       'freetime', 'absences', 'G1', 'G2', 'G3'],
       y_vars=['school', 'sex', 'address', 'Mjob', 'Fjob', 'higher', 'studytime',
       'freetime', 'absences', 'G1', 'G2', 'G3'],
       diag_kind='kde'
)

# %%
# Pairplot for all the data

sns.pairplot(mathData,
    x_vars=['higher', 'studytime','freetime', 'absences'],
       y_vars=['G1', 'G2', 'G3'],
       diag_kind='kde',hue='G1'
)

# %%
#Strip PLot --> plotting a graph
sns.stripplot(y='G1',x='G3',data=mathData,hue='G2')

# %%
#Subplots --> Plotting subplots together

fig, axarr = plt.subplots(3,2,figsize=(10,10))
sns.stripplot(y='G1',x='G2',data=mathData,hue=None,ax=axarr[0][0])
sns.stripplot(y='G1',x='G3',data=mathData,hue=None,ax=axarr[0][1])

sns.stripplot(y='higher',x='G3',data=mathData,hue=None,ax=axarr[1][0])
sns.stripplot(y='freetime',x='G3',data=mathData,hue=None,ax=axarr[1][1])
sns.stripplot(y='studytime',x='G3',data=mathData,hue=None,ax=axarr[2][0])
sns.stripplot(y='absences',x='G3',data=mathData,hue=None,ax=axarr[2][1])

# %%
# 80-20 test-train data split
trainData = mathData.sample(frac=0.8,random_state=0)
testData = mathData.drop(trainData.index)
print(trainData)
print(testData)
# Out:
#      school  sex  address  Mjob  Fjob  ...  freetime  absences  G1  G2  G3
# 329       1    1        1     5     5  ...         3         4  14  14  14
# 318       1    1        0     1     4  ...         3         0  11  11  10
# 317       1    1        1     3     3  ...         3         9   9  10   9
# 65        1    1        1     5     4  ...         4         2  16  15  15
# 59        1    1        1     4     3  ...         2         2  15  16  16
# ..      ...  ...      ...   ...   ...  ...       ...       ...  ..  ..  ..
# 279       1    0        1     5     4  ...         2         8  10  11  10
# 227       1    0        1     4     4  ...         3         2  12  11  12
# 148       1    0        1     5     5  ...         3         0   7   6   0
# 143       1    1        1     1     1  ...         4         2  14  14  13
# 180       1    0        1     5     3  ...         4        10   9   8   8
#
# [316 rows x 12 columns]
#      school  sex  address  Mjob  Fjob  ...  freetime  absences  G1  G2  G3
# 9         1    0        1     3     3  ...         5         0  14  15  15
# 25        1    1        1     4     4  ...         2        14   6   9   8
# 28        1    0        1     4     3  ...         3         4  11  11  11
# 31        1    0        1     4     4  ...         3         0  17  16  17
# 32        1    0        0     5     1  ...         5         0  17  16  16
# ..      ...  ...      ...   ...   ...  ...       ...       ...  ..  ..  ..
# 365       0    0        0     1     3  ...         3         4  10  10  10
# 367       0    1        0     3     4  ...         2         0   7   6   0
# 379       0    1        0     1     3  ...         5        17  10  10  10
# 381       0    0        0     3     3  ...         4         5   7   6   7
# 393       0    0        0     4     3  ...         4         0  11  12  10
#
# [79 rows x 12 columns]

# %%
print(trainData.shape)
print(testData.shape)
# Out:
# (316, 12)
# (79, 12)

# %%
trainFeatures=trainData.copy()
testFeatures=testData.copy()
print(trainFeatures.head())
print(testFeatures.head())
# Out:
#      school  sex  address  Mjob  Fjob  ...  freetime  absences  G1  G2  G3
# 329       1    1        1     5     5  ...         3         4  14  14  14
# 318       1    1        0     1     4  ...         3         0  11  11  10
# 317       1    1        1     3     3  ...         3         9   9  10   9
# 65        1    1        1     5     4  ...         4         2  16  15  15
# 59        1    1        1     4     3  ...         2         2  15  16  16
#
# [5 rows x 12 columns]
#     school  sex  address  Mjob  Fjob  ...  freetime  absences  G1  G2  G3
# 9        1    0        1     3     3  ...         5         0  14  15  15
# 25       1    1        1     4     4  ...         2        14   6   9   8
# 28       1    0        1     4     3  ...         3         4  11  11  11
# 31       1    0        1     4     4  ...         3         0  17  16  17
# 32       1    0        0     5     1  ...         5         0  17  16  16
#
# [5 rows x 12 columns]

# %%
# Removing the G3 column and saving it in labels
trainLabel=trainFeatures.pop('G3')
testLabel=testFeatures.pop('G3')
print(trainLabel.head())
print(testLabel.head())
# Out:
# 329    14
# 318    10
# 317     9
# 65     15
# 59     16
# Name: G3, dtype: int64
# 9     15
# 25     8
# 28    11
# 31    17
# 32    16
# Name: G3, dtype: int64

# %%
print(trainFeatures.head())
print(testFeatures.head())
# Out:
#      school  sex  address  Mjob  Fjob  ...  studytime  freetime  absences  G1  G2
# 329       1    1        1     5     5  ...          3         3         4  14  14
# 318       1    1        0     1     4  ...          3         3         0  11  11
# 317       1    1        1     3     3  ...          3         3         9   9  10
# 65        1    1        1     5     4  ...          2         4         2  16  15
# 59        1    1        1     4     3  ...          2         2         2  15  16
#
# [5 rows x 11 columns]
#     school  sex  address  Mjob  Fjob  ...  studytime  freetime  absences  G1  G2
# 9        1    0        1     3     3  ...          2         5         0  14  15
# 25       1    1        1     4     4  ...          1         2        14   6   9
# 28       1    0        1     4     3  ...          2         3         4  11  11
# 31       1    0        1     4     4  ...          2         3         0  17  16
# 32       1    0        0     5     1  ...          2         5         0  17  16
#
# [5 rows x 11 columns]

# %% [markdown]
# $G3_i = G1_i \times \theta_1 + \theta_0$

# %%
# For univariate problem will consider only G1 and G3
uniMathData = mathData[['G1','G3']]
uniMathData.to_csv('univariate_MathData_2.csv')

# %%
ls
# Out:
# cleanMathData.csv   student-merge.R  univariate_MathData_2.csv
# student-mat.csv     student-por.csv
# student-mat.gsheet  student.txt

# %%
sns.pairplot(uniMathData,
             x_vars=['G1','G3'],
             y_vars=['G1','G3'],
             diag_kind='kde'
             )

# %%
uniTrainData = uniMathData.sample(frac=0.8,random_state=0)
uniTestData = uniMathData.drop(labels=uniTrainData.index)

# %%
print(uniTrainData.head())
print(uniTestData.head())
# Out:
#      G1  G3
# 329  14  14
# 318  11  10
# 317   9   9
# 65   16  15
# 59   15  16
#     G1  G3
# 9   14  15
# 25   6   8
# 28  11  11
# 31  17  17
# 32  17  16

# %%
uniTrainFeatures=uniTrainData.copy()
uniTestFeatures=uniTestData.copy()
print(uniTrainFeatures.head())
print(uniTestFeatures.head())
# Out:
#      G1  G3
# 329  14  14
# 318  11  10
# 317   9   9
# 65   16  15
# 59   15  16
#     G1  G3
# 9   14  15
# 25   6   8
# 28  11  11
# 31  17  17
# 32  17  16

# %%
uniTrainLabels=uniTrainFeatures.pop('G3')
uniTestLabels=uniTestFeatures.pop('G3')

# %%
print(uniTrainLabels.head())
print(uniTestLabels.head())
# Out:
# 329    14
# 318    10
# 317     9
# 65     15
# 59     16
# Name: G3, dtype: int64
# 9     15
# 25     8
# 28    11
# 31    17
# 32    16
# Name: G3, dtype: int64

# %%
# univariate --> num(features) = 1
# multivariate --> num(features) >1
model= tf.keras.Sequential([
                            tf.keras.layers.Dense('1')
])

# %%
model.compile(
    loss='mean_absolute_error',
    optimizer = tf.keras.optimizers.Adam(0.001),
    metrics=['mae','mse']

)

# %%
numEpochs=200
history = model.fit(x=uniTrainFeatures,y=uniTrainLabels, validation_data=(uniTestFeatures,uniTestLabels), epochs=numEpochs)
# Out:
# Epoch 1/200
# 10/10 [==============================] - 1s
200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.4936 - mae: 3.4936 - mse: 15.3744 - val_loss: 3.3772 - val_mae: 3.3772 - val_mse: 13.7744
# Epoch 98/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.4064 - mae: 3.4064 - mse: 14.8128 - val_loss: 3.2765 - val_mae: 3.2765 - val_mse: 13.1378
# Epoch 99/200
# 10/10 [==============================] - 0s 5ms/step - loss: 3.3176 - mae: 3.3176 - mse: 14.2614 - val_loss: 3.1761 - val_mae: 3.1761 - val_mse: 12.5314
# Epoch 100/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.2296 - mae: 3.2296 - mse: 13.7300 - val_loss: 3.0777 - val_mae: 3.0777 - val_mse: 11.9655
# Epoch 101/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.1422 - mae: 3.1422 - mse: 13.2219 - val_loss: 2.9825 - val_mae: 2.9825 - val_mse: 11.4384
# Epoch 102/200
# 10/10 [==============================] - 0s 4ms/step - loss: 3.0614 - mae: 3.0614 - mse: 12.7889 - val_loss: 2.8840 - val_mae: 2.8840 - val_mse: 10.9099
# Epoch 103/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.9753 - mae: 2.9753 - mse: 12.3319 - val_loss: 2.7882 - val_mae: 2.7882 - val_mse: 10.4242
# Epoch 104/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8902 - mae: 2.8902 - mse: 11.8960 - val_loss: 2.7008 - val_mae: 2.7008 - val_mse: 9.9919
# Epoch 105/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.8129 - mae: 2.8129 - mse: 11.5185 - val_loss: 2.6162 - val_mae: 2.6162 - val_mse: 9.5867
# Epoch 106/200
# 10/10 [==============================] - 0s 5ms/step - loss: 2.7387 - mae: 2.7387 - mse: 11.1739 - val_loss: 2.5321 - val_mae: 2.5321 - val_mse: 9.2052
# Epoch 107/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.6615 - mae: 2.6615 - mse: 10.8366 - val_loss: 2.4506 - val_mae: 2.4506 - val_mse: 8.8590
# Epoch 108/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.5917 - mae: 2.5917 - mse: 10.5524 - val_loss: 2.3662 - val_mae: 2.3662 - val_mse: 8.5255
# Epoch 109/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.5174 - mae: 2.5174 - mse: 10.2512 - val_loss: 2.2855 - val_mae: 2.2855 - val_mse: 8.2298
# Epoch 110/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.4513 - mae: 2.4513 - mse: 10.0088 - val_loss: 2.2069 - val_mae: 2.2069 - val_mse: 7.9623
# Epoch 111/200
# 10/10 [==============================] - 0s 5ms/step - loss: 2.3900 - mae: 2.3900 - mse: 9.7807 - val_loss: 2.1337 - val_mae: 2.1337 - val_mse: 7.7290
# Epoch 112/200
# 10/10 [==============================] - 0s 5ms/step - loss: 2.3332 - mae: 2.3332 - mse: 9.5800 - val_loss: 2.0631 - val_mae: 2.0631 - val_mse: 7.5225
# Epoch 113/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2811 - mae: 2.2811 - mse: 9.4086 - val_loss: 1.9969 - val_mae: 1.9969 - val_mse: 7.3395
# Epoch 114/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.2352 - mae: 2.2352 - mse: 9.2451 - val_loss: 1.9389 - val_mae: 1.9389 - val_mse: 7.1882
# Epoch 115/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1940 - mae: 2.1940 - mse: 9.1241 - val_loss: 1.8817 - val_mae: 1.8817 - val_mse: 7.0524
# Epoch 116/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.1560 - mae: 2.1560 - mse: 9.0159 - val_loss: 1.8321 - val_mae: 1.8321 - val_mse: 6.9396
# Epoch 117/200
# 10/10 [==============================] - 0s 5ms/step - loss: 2.1240 - mae: 2.1240 - mse: 8.9205 - val_loss: 1.7865 - val_mae: 1.7865 - val_mse: 6.8457
# Epoch 118/200
# 10/10 [==============================] - 0s 5ms/step - loss: 2.0960 - mae: 2.0960 - mse: 8.8417 - val_loss: 1.7497 - val_mae: 1.7497 - val_mse: 6.7642
# Epoch 119/200
# 10/10 [==============================] - 0s 5ms/step - loss: 2.0691 - mae: 2.0691 - mse: 8.7721 - val_loss: 1.7216 - val_mae: 1.7216 - val_mse: 6.6979
# Epoch 120/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0437 - mae: 2.0437 - mse: 8.7186 - val_loss: 1.6955 - val_mae: 1.6955 - val_mse: 6.6421
# Epoch 121/200
# 10/10 [==============================] - 0s 5ms/step - loss: 2.0228 - mae: 2.0228 - mse: 8.6771 - val_loss: 1.6726 - val_mae: 1.6726 - val_mse: 6.5920
# Epoch 122/200
# 10/10 [==============================] - 0s 4ms/step - loss: 2.0009 - mae: 2.0009 - mse: 8.6312 - val_loss: 1.6527 - val_mae: 1.6527 - val_mse: 6.5540
# Epoch 123/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.9828 - mae: 1.9828 - mse: 8.6080 - val_loss: 1.6375 - val_mae: 1.6375 - val_mse: 6.5254
# Epoch 124/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9684 - mae: 1.9684 - mse: 8.5858 - val_loss: 1.6229 - val_mae: 1.6229 - val_mse: 6.5035
# Epoch 125/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.9542 - mae: 1.9542 - mse: 8.5644 - val_loss: 1.6123 - val_mae: 1.6123 - val_mse: 6.4889
# Epoch 126/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9436 - mae: 1.9436 - mse: 8.5544 - val_loss: 1.6051 - val_mae: 1.6051 - val_mse: 6.4799
# Epoch 127/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9357 - mae: 1.9357 - mse: 8.5458 - val_loss: 1.5996 - val_mae: 1.5996 - val_mse: 6.4743
# Epoch 128/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9292 - mae: 1.9292 - mse: 8.5454 - val_loss: 1.5981 - val_mae: 1.5981 - val_mse: 6.4719
# Epoch 129/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9233 - mae: 1.9233 - mse: 8.5403 - val_loss: 1.5969 - val_mae: 1.5969 - val_mse: 6.4717
# Epoch 130/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9194 - mae: 1.9194 - mse: 8.5434 - val_loss: 1.5959 - val_mae: 1.5959 - val_mse: 6.4736
# Epoch 131/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9143 - mae: 1.9143 - mse: 8.5464 - val_loss: 1.5962 - val_mae: 1.5962 - val_mse: 6.4768
# Epoch 132/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9107 - mae: 1.9107 - mse: 8.5470 - val_loss: 1.5965 - val_mae: 1.5965 - val_mse: 6.4803
# Epoch 133/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9079 - mae: 1.9079 - mse: 8.5501 - val_loss: 1.5968 - val_mae: 1.5968 - val_mse: 6.4853
# Epoch 134/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.9055 - mae: 1.9055 - mse: 8.5572 - val_loss: 1.5971 - val_mae: 1.5971 - val_mse: 6.4924
# Epoch 135/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.9024 - mae: 1.9024 - mse: 8.5645 - val_loss: 1.5974 - val_mae: 1.5974 - val_mse: 6.5006
# Epoch 136/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8984 - mae: 1.8984 - mse: 8.5702 - val_loss: 1.5977 - val_mae: 1.5977 - val_mse: 6.5072
# Epoch 137/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8965 - mae: 1.8965 - mse: 8.5763 - val_loss: 1.6003 - val_mae: 1.6003 - val_mse: 6.5164
# Epoch 138/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8948 - mae: 1.8948 - mse: 8.5832 - val_loss: 1.6022 - val_mae: 1.6022 - val_mse: 6.5236
# Epoch 139/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8938 - mae: 1.8938 - mse: 8.5917 - val_loss: 1.6043 - val_mae: 1.6043 - val_mse: 6.5318
# Epoch 140/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8922 - mae: 1.8922 - mse: 8.5979 - val_loss: 1.6059 - val_mae: 1.6059 - val_mse: 6.5388
# Epoch 141/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.8911 - mae: 1.8911 - mse: 8.6066 - val_loss: 1.6077 - val_mae: 1.6077 - val_mse: 6.5468
# Epoch 142/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8898 - mae: 1.8898 - mse: 8.6112 - val_loss: 1.6092 - val_mae: 1.6092 - val_mse: 6.5544
# Epoch 143/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8888 - mae: 1.8888 - mse: 8.6193 - val_loss: 1.6112 - val_mae: 1.6112 - val_mse: 6.5645
# Epoch 144/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8878 - mae: 1.8878 - mse: 8.6275 - val_loss: 1.6132 - val_mae: 1.6132 - val_mse: 6.5715
# Epoch 145/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8874 - mae: 1.8874 - mse: 8.6323 - val_loss: 1.6145 - val_mae: 1.6145 - val_mse: 6.5757
# Epoch 146/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8872 - mae: 1.8872 - mse: 8.6358 - val_loss: 1.6155 - val_mae: 1.6155 - val_mse: 6.5792
# Epoch 147/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8870 - mae: 1.8870 - mse: 8.6379 - val_loss: 1.6163 - val_mae: 1.6163 - val_mse: 6.5819
# Epoch 148/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8870 - mae: 1.8870 - mse: 8.6400 - val_loss: 1.6167 - val_mae: 1.6167 - val_mse: 6.5829
# Epoch 149/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8869 - mae: 1.8869 - mse: 8.6422 - val_loss: 1.6183 - val_mae: 1.6183 - val_mse: 6.5885
# Epoch 150/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8871 - mae: 1.8871 - mse: 8.6520 - val_loss: 1.6200 - val_mae: 1.6200 - val_mse: 6.5948
# Epoch 151/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8863 - mae: 1.8863 - mse: 8.6513 - val_loss: 1.6204 - val_mae: 1.6204 - val_mse: 6.5960
# Epoch 152/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8862 - mae: 1.8862 - mse: 8.6527 - val_loss: 1.6210 - val_mae: 1.6210 - val_mse: 6.5981
# Epoch 153/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8862 - mae: 1.8862 - mse: 8.6567 - val_loss: 1.6225 - val_mae: 1.6225 - val_mse: 6.6039
# Epoch 154/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8859 - mae: 1.8859 - mse: 8.6600 - val_loss: 1.6228 - val_mae: 1.6228 - val_mse: 6.6047
# Epoch 155/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8861 - mae: 1.8861 - mse: 8.6643 - val_loss: 1.6248 - val_mae: 1.6248 - val_mse: 6.6125
# Epoch 156/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8855 - mae: 1.8855 - mse: 8.6670 - val_loss: 1.6252 - val_mae: 1.6252 - val_mse: 6.6140
# Epoch 157/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8857 - mae: 1.8857 - mse: 8.6722 - val_loss: 1.6270 - val_mae: 1.6270 - val_mse: 6.6211
# Epoch 158/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8853 - mae: 1.8853 - mse: 8.6740 - val_loss: 1.6270 - val_mae: 1.6270 - val_mse: 6.6210
# Epoch 159/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8851 - mae: 1.8851 - mse: 8.6752 - val_loss: 1.6276 - val_mae: 1.6276 - val_mse: 6.6235
# Epoch 160/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8850 - mae: 1.8850 - mse: 8.6795 - val_loss: 1.6291 - val_mae: 1.6291 - val_mse: 6.6294
# Epoch 161/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8848 - mae: 1.8847 - mse: 8.6841 - val_loss: 1.6299 - val_mae: 1.6299 - val_mse: 6.6328
# Epoch 162/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.8846 - mae: 1.8846 - mse: 8.6854 - val_loss: 1.6302 - val_mae: 1.6302 - val_mse: 6.6340
# Epoch 163/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8847 - mae: 1.8847 - mse: 8.6873 - val_loss: 1.6304 - val_mae: 1.6304 - val_mse: 6.6343
# Epoch 164/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8846 - mae: 1.8846 - mse: 8.6851 - val_loss: 1.6299 - val_mae: 1.6299 - val_mse: 6.6321
# Epoch 165/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8846 - mae: 1.8846 - mse: 8.6842 - val_loss: 1.6302 - val_mae: 1.6302 - val_mse: 6.6331
# Epoch 166/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8845 - mae: 1.8845 - mse: 8.6850 - val_loss: 1.6297 - val_mae: 1.6297 - val_mse: 6.6306
# Epoch 167/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.8845 - mae: 1.8845 - mse: 8.6831 - val_loss: 1.6297 - val_mae: 1.6297 - val_mse: 6.6304
# Epoch 168/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8844 - mae: 1.8844 - mse: 8.6832 - val_loss: 1.6299 - val_mae: 1.6299 - val_mse: 6.6308
# Epoch 169/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8844 - mae: 1.8844 - mse: 8.6840 - val_loss: 1.6300 - val_mae: 1.6300 - val_mse: 6.6311
# Epoch 170/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8844 - mae: 1.8844 - mse: 8.6822 - val_loss: 1.6293 - val_mae: 1.6293 - val_mse: 6.6277
# Epoch 171/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8844 - mae: 1.8844 - mse: 8.6816 - val_loss: 1.6298 - val_mae: 1.6298 - val_mse: 6.6296
# Epoch 172/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8843 - mae: 1.8843 - mse: 8.6831 - val_loss: 1.6300 - val_mae: 1.6300 - val_mse: 6.6301
# Epoch 173/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8842 - mae: 1.8842 - mse: 8.6818 - val_loss: 1.6295 - val_mae: 1.6295 - val_mse: 6.6275
# Epoch 174/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8843 - mae: 1.8843 - mse: 8.6796 - val_loss: 1.6295 - val_mae: 1.6295 - val_mse: 6.6275
# Epoch 175/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8842 - mae: 1.8842 - mse: 8.6809 - val_loss: 1.6298 - val_mae: 1.6298 - val_mse: 6.6283
# Epoch 176/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8842 - mae: 1.8842 - mse: 8.6805 - val_loss: 1.6296 - val_mae: 1.6296 - val_mse: 6.6274
# Epoch 177/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8844 - mae: 1.8844 - mse: 8.6790 - val_loss: 1.6294 - val_mae: 1.6294 - val_mse: 6.6258
# Epoch 178/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.8841 - mae: 1.8841 - mse: 8.6807 - val_loss: 1.6305 - val_mae: 1.6305 - val_mse: 6.6300
# Epoch 179/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8843 - mae: 1.8843 - mse: 8.6817 - val_loss: 1.6296 - val_mae: 1.6296 - val_mse: 6.6262
# Epoch 180/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8840 - mae: 1.8840 - mse: 8.6794 - val_loss: 1.6296 - val_mae: 1.6296 - val_mse: 6.6261
# Epoch 181/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8840 - mae: 1.8840 - mse: 8.6784 - val_loss: 1.6293 - val_mae: 1.6293 - val_mse: 6.6245
# Epoch 182/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8840 - mae: 1.8840 - mse: 8.6785 - val_loss: 1.6296 - val_mae: 1.6296 - val_mse: 6.6252
# Epoch 183/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8840 - mae: 1.8840 - mse: 8.6785 - val_loss: 1.6299 - val_mae: 1.6299 - val_mse: 6.6260
# Epoch 184/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8839 - mae: 1.8839 - mse: 8.6778 - val_loss: 1.6292 - val_mae: 1.6292 - val_mse: 6.6228
# Epoch 185/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.8838 - mae: 1.8838 - mse: 8.6774 - val_loss: 1.6294 - val_mae: 1.6294 - val_mse: 6.6234
# Epoch 186/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.8838 - mae: 1.8838 - mse: 8.6770 - val_loss: 1.6296 - val_mae: 1.6296 - val_mse: 6.6242
# Epoch 187/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8840 - mae: 1.8840 - mse: 8.6799 - val_loss: 1.6297 - val_mae: 1.6297 - val_mse: 6.6243
# Epoch 188/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8839 - mae: 1.8839 - mse: 8.6752 - val_loss: 1.6289 - val_mae: 1.6289 - val_mse: 6.6205
# Epoch 189/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8838 - mae: 1.8838 - mse: 8.6763 - val_loss: 1.6296 - val_mae: 1.6296 - val_mse: 6.6229
# Epoch 190/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.8838 - mae: 1.8838 - mse: 8.6736 - val_loss: 1.6287 - val_mae: 1.6287 - val_mse: 6.6187
# Epoch 191/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.8837 - mae: 1.8837 - mse: 8.6747 - val_loss: 1.6294 - val_mae: 1.6294 - val_mse: 6.6216
# Epoch 192/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8836 - mae: 1.8836 - mse: 8.6743 - val_loss: 1.6293 - val_mae: 1.6293 - val_mse: 6.6206
# Epoch 193/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8837 - mae: 1.8837 - mse: 8.6766 - val_loss: 1.6298 - val_mae: 1.6298 - val_mse: 6.6224
# Epoch 194/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8838 - mae: 1.8838 - mse: 8.6723 - val_loss: 1.6281 - val_mae: 1.6281 - val_mse: 6.6148
# Epoch 195/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8838 - mae: 1.8838 - mse: 8.6679 - val_loss: 1.6278 - val_mae: 1.6278 - val_mse: 6.6130
# Epoch 196/200
# 10/10 [==============================] - 0s 7ms/step - loss: 1.8836 - mae: 1.8836 - mse: 8.6715 - val_loss: 1.6297 - val_mae: 1.6297 - val_mse: 6.6209
# Epoch 197/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8834 - mae: 1.8834 - mse: 8.6730 - val_loss: 1.6287 - val_mae: 1.6287 - val_mse: 6.6164
# Epoch 198/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.8835 - mae: 1.8835 - mse: 8.6695 - val_loss: 1.6286 - val_mae: 1.6286 - val_mse: 6.6159
# Epoch 199/200
# 10/10 [==============================] - 0s 5ms/step - loss: 1.8833 - mae: 1.8833 - mse: 8.6722 - val_loss: 1.6297 - val_mae: 1.6297 - val_mse: 6.6200
# Epoch 200/200
# 10/10 [==============================] - 0s 6ms/step - loss: 1.8833 - mae: 1.8833 - mse: 8.6723 - val_loss: 1.6288 - val_mae: 1.6288 - val_mse: 6.6161

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
def curvePlots(tempString):
  plt.plot(history.history[tempString])
  plt.plot(history.history[f'val_{tempString}'])
  plt.xlabel('NumEpochs')
  plt.ylabel(tempString)
  plt.legend([tempString, f'val_{tempString}'])
  plt.show()


curvePlots('mse')
curvePlots('mae')
curvePlots('loss')

# %%
testPreds=model.predict(uniTestFeatures).flatten()

# %%
def predPlot(labels, predictions):
  plt.scatter(labels, predictions)
  plt.ylabel('Predictions')
  plt.xlabel('True Value or Labels')
  plt.axis('equal')
  plt.axis('square')
  plt.xlim([0, plt.xlim()[1]])
  plt.ylim([0, plt.ylim()[1]])
  plt.show()

predPlot(uniTestLabels, testPreds)

# %%
#error plot --> gaussian distribution 

def errorPlot(preds, labels, counts):
  errors = preds - labels
  plt.hist(errors, counts)
  plt.xlabel('Error')
  plt.ylabel('Counts')
  plt.show()

errorPlot(testPreds, uniTestLabels, numEpochs)
